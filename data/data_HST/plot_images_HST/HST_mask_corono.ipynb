# %%
from import_functions_plotting import *

# %%
L = time.localtime()
date = "{}-{}-{}".format(L[0],L[1],L[2],L[3],L[4],L[5])

saving_dir = 'figs/fig_v{}/'.format(date)
os.makedirs(saving_dir,exist_ok=True)

# %% [markdown]
# # Initialization

# %%
# Path folder results
#folder = 'results/2023-7-27-20h33min20s_job6_mask_2_30_WedgeA10_cADI_crj'
#folder = 'results/2023-7-31-23h1min0s_job6_mask_2_30_WedgeA10_cADI_crj'
folder = 'results/2023-7-31-23h10min2s_job7_mask_2_30_WedgeA10_cADI_crj_ext_pix_oversize'
d_star = 107.4
platescale = 0.05078


scalebar_arcsec = 2
scalebar_leg = '2"'
scalebar_xtext, scalebar_ytext, scalebar_text = 0.03, 0.15, '{:.0f} au'.format(scalebar_arcsec*d_star)
scalebar_sep = 4
scalebar_pad = 0.1
figsize = (3.5,3.5)
scalebar_color = 'black'
                    
clab = 'arbitrary'
im_crop = 0 #112

xtext, ytext = 0.03, 0.92

# load specific stuff for synthethic population models
n_colors = 5
list_colors = ['black', 'gray', [0.8,0.9,1]]
palette,cmap,COLORS = define_color_shades(list_colors, n_colors, show=0, blend=True)

# cmaps
cmap =  seaborn.blend_palette(list_colors , as_cmap=True)
display(cmap)

# %% [markdown]
# # HST results
#
# ## Science

# %%
FNs = ['IM1_ORIENT1', 'IM2_ORIENT2',
       'IM1_derot', 'IM2_derot',
       'IM12_derot', 'IM21_derot',
       'IM_cadi_derot', 'im_obs_mask_min_final', 'im_obs_mask_max_final'
        ]

LABELs = ['image 1 (roll 1)', 'image 2 (roll 2)',
          'image 1 (derotated)', 'image 2 (derotated)',
          'image 1 - image 2 (derotated)', 'image 2 - image 1 (derotated)',
          'processed image (derotated)',  'processed image (derotated)',  'processed image (derotated)'
         ]

IMs = [ fits.getdata( '{}/{}.fits'.format(folder, fn)) for fn in FNs]

# %% [markdown]
# ### Figure IM1_ORIENT1

# %%
# Figure IM1_ORIENT1
for i in range(2):
    fn = FNs[i]
    im = IMs[i] ; print(np.shape(im))
    text = LABELs[i]
    namesave = fn

    vmin, vmax = 0, 2000 #-10, 10
    
    fig, ax = plot_fig(im=im, clab=clab, vmin=vmin, vmax=vmax, 
             im_crop=im_crop, saving_dir=saving_dir, namesave=namesave,
             add_colorbar=0, do_tight_layout=0,
            scalebar_arcsec=scalebar_arcsec, scalebar_leg=scalebar_leg, scalebar_label_top=False, scalebar_sep=6,
            platescale=platescale, return_fig_ax=True,
            #right=right
            )
    
    ax.text(scalebar_xtext, scalebar_ytext, scalebar_text, transform=ax.transAxes, color='white')
    
    
    ax.text(xtext, ytext, text, transform=ax.transAxes, color='white')
    
    plt.savefig(saving_dir+fn+'.pdf',dpi=200)
# Out:
# (296, 296)
# (296, 296)

# %% [markdown]
# ### Figure IM1_derot

# %%
# Figure IM1_derot
for i in range(2,4):
    fn = FNs[i]
    im = IMs[i] ; print(np.shape(im))
    text = LABELs[i]
    namesave = fn

    vmin, vmax = 0, 2000 #-10, 10
    
    fig, ax = plot_fig(im=im, clab=clab, vmin=vmin, vmax=vmax, 
             im_crop=im_crop, saving_dir=saving_dir, namesave=namesave,
             add_colorbar=0, do_tight_layout=0,
            scalebar_arcsec=scalebar_arcsec, scalebar_leg=scalebar_leg, scalebar_label_top=False, scalebar_sep=6,
            platescale=platescale, return_fig_ax=True,
            #right=right
            )
    
    ax.text(scalebar_xtext, scalebar_ytext, scalebar_text, transform=ax.transAxes, color='white')
    
    
    ax.text(xtext, ytext, text, transform=ax.transAxes, color='white')
    
    plt.savefig(saving_dir+fn+'.pdf',dpi=200)
# Out:
# (296, 296)
# (296, 296)

# %% [markdown]
# ### derot(IM1-IM2)

# %%
# Figure derot(IM1-IM2)
for i in range(4,6):
    fn = FNs[i]
    im = IMs[i] ; print(np.shape(im))
    text = LABELs[i]
    namesave = fn

    vmin, vmax = 0, 50 #-10, 10
    
    fig, ax = plot_fig(im=im, clab=clab, vmin=vmin, vmax=vmax, 
             im_crop=im_crop, saving_dir=saving_dir, namesave=namesave,
             add_colorbar=0, do_tight_layout=0,
            scalebar_arcsec=scalebar_arcsec, scalebar_leg=scalebar_leg, scalebar_label_top=False, scalebar_sep=6,
            platescale=platescale, return_fig_ax=True,
            #right=right
            )
    
    ax.text(scalebar_xtext, scalebar_ytext, scalebar_text, transform=ax.transAxes, color='white')
    
    
    ax.text(xtext, ytext, text, transform=ax.transAxes, color='white')
    
    plt.savefig(saving_dir+fn+'.pdf',dpi=200)
# Out:
# (296, 296)
# (296, 296)

# %% [markdown]
# ### Processed image

# %%
# Figure mean ( derot(IM1-IM2) + derot(IM2-IM1) )
for i in range(6,9):
    fn = FNs[i]
    im = IMs[i] ; print(np.shape(im))
    text = LABELs[i]
    namesave = fn

    vmin, vmax = 0, 50
    
    fig, ax = plot_fig(im=im, clab=clab, vmin=vmin, vmax=vmax, 
             im_crop=im_crop, saving_dir=saving_dir, namesave=namesave,
             add_colorbar=0, do_tight_layout=0,
            scalebar_arcsec=scalebar_arcsec, scalebar_leg=scalebar_leg, scalebar_label_top=False, scalebar_sep=6,
            platescale=platescale, return_fig_ax=True,
            #right=right
            )
    
    ax.text(scalebar_xtext, scalebar_ytext, scalebar_text, transform=ax.transAxes, color='white')
    
    
    ax.text(xtext, ytext, text, transform=ax.transAxes, color='white')
    
    plt.savefig(saving_dir+fn+'.pdf',dpi=200)
# Out:
# (296, 296)
# (296, 296)
# (296, 296)

# %%
0.6*86
# Out:
# 51.6

# %% [markdown]
# ## Masks

# %%
FNs_MASK = ['mask', 'mask_cube_rot', 
       'mask_gradient_final', 'mask_max_binary_final', 'mask_min_binary_final',
       'spiders', 'spiders_cube_rot', 
       'spiders_gradient_final', 'spiders_max_binary_final', 'spiders_min_binary_final',
       'mask+spiders', 
        'mask+spiders_cube_rot', 
       'mask+spiders_gradient_final', 'mask+spiders_max_binary_final', 'mask+spiders_min_binary_final',
        ]

LABELs = ['mask', ['mask (roll 1 deproj.)', 'mask (roll 2 deproj.)'],
          'gradient mask \n(roll 1 and 2 deproj.)', 'mask occults at least once', 'mask always occults',
          'spiders',
          ['spiders (roll 1 deproj.)', 'spiders (roll 2 deproj.)'],
          'gradient spiders \n(roll 1 and 2 deproj.)', 'spiders occult at least once', 'spiders always occult',
          'mask+spiders', 
          ['mask+spiders (roll 1 deproj.)', 'mask+spiders (roll 2 deproj.)'],
          'gradient mask+spiders \n(roll 1 and 2 deproj.)', 'mask+spiders occult\nat least once', 'mask+spiders always\n occulted',
         ]

MASKs = [ fits.getdata( '{}/{}.fits'.format(folder, fn)) for fn in FNs_MASK]

# %% [markdown]
# ### Full mask

# %%
# Figure mean ( derot(IM1-IM2) + derot(IM2-IM1) )
for i in range(1):
    fn = FNs_MASK[i]
    im = MASKs[i] ; print(np.shape(im))
    text = LABELs[i]
    namesave = fn

    vmin, vmax = 0, 50
    
    fig, ax = plot_fig(im=im, clab=clab, vmin=vmin, vmax=vmax, figsize=figsize,
             im_crop=im_crop, saving_dir=saving_dir, namesave=namesave,
             add_colorbar=0, do_tight_layout=0, scalebar_color=scalebar_color,
            scalebar_arcsec=scalebar_arcsec, scalebar_leg=scalebar_leg, scalebar_label_top=False, 
            scalebar_sep= scalebar_sep, scalebar_pad= scalebar_pad, cmap=cmap,
            platescale=platescale, return_fig_ax=True, 
            #right=right
            )
    
    ax.text(scalebar_xtext, scalebar_ytext, scalebar_text, transform=ax.transAxes, color=scalebar_color)
    
    
    ax.text(xtext, ytext, text, transform=ax.transAxes, color=scalebar_color)
    
    plt.savefig(saving_dir+namesave+'.pdf',dpi=200)
# Out:
# (296, 296)

# %% [markdown]
# ### Wedge for the different rolling angles

# %%
# Figure mean ( derot(IM1-IM2) + derot(IM2-IM1) )
for i in range(1,2):
    fn = FNs_MASK[i]
    cube = MASKs[i] ; print(np.shape(im))
    for j in range(len(cube)):
        im = cube[j]
        text = LABELs[i][j]
        namesave = fn+str(j)

        vmin, vmax = 0, 50
    
        fig, ax = plot_fig(im=im, clab=clab, vmin=vmin, vmax=vmax, figsize = figsize, 
            im_crop=im_crop, saving_dir=saving_dir, namesave=namesave,
             add_colorbar=0, do_tight_layout=0, scalebar_color=scalebar_color,
            scalebar_arcsec=scalebar_arcsec, scalebar_leg=scalebar_leg, scalebar_label_top=False, 
            scalebar_sep=scalebar_sep, scalebar_pad = scalebar_pad, cmap=cmap,
            platescale=platescale, return_fig_ax=True, 
            #right=right
            )
        
        ax.text(scalebar_xtext, scalebar_ytext, scalebar_text, transform=ax.transAxes, color=scalebar_color)
        ax.text(xtext, ytext, text, transform=ax.transAxes, color=scalebar_color)
    
        if j == 0 or j: ax.text(xtext, ytext, text, transform=ax.transAxes, color='grey')
        
        plt.savefig(saving_dir+namesave+'.pdf',dpi=200)
# Out:
# (296, 296)

# %%
# Figure mean ( derot(IM1-IM2) + derot(IM2-IM1) )
for i in range(2,5):
    fn = FNs_MASK[i]
    im = MASKs[i] ; print(np.shape(im))
    text = LABELs[i]
    namesave = fn

    vmin, vmax = 0, None
    
    fig, ax = plot_fig(im=im, clab=clab, vmin=vmin, vmax=vmax, figsize=figsize,
             im_crop=im_crop, saving_dir=saving_dir, namesave=namesave,
             add_colorbar=0, do_tight_layout=0, scalebar_color=scalebar_color,
            scalebar_arcsec=scalebar_arcsec, scalebar_leg=scalebar_leg, scalebar_label_top=False, 
            scalebar_sep= scalebar_sep, scalebar_pad= scalebar_pad, cmap=cmap,
            platescale=platescale, return_fig_ax=True, 
            #right=right
            )
        
    ax.text(scalebar_xtext, scalebar_ytext, scalebar_text, transform=ax.transAxes, color=scalebar_color)
    
    if 'gradient' in text: bonus=-0.08
    else: bonus=0
    ax.text(xtext, ytext+bonus, text, transform=ax.transAxes, color=scalebar_color)
    if 'occult' in text: ax.text(xtext, ytext, text, transform=ax.transAxes, color='grey')
    
    plt.savefig(saving_dir+namesave+'.pdf',dpi=200)
# Out:
# (296, 296)
# (296, 296)
# (296, 296)

# %%
np.shape(cube)
# Out:
# (2, 296, 296)

# %% [markdown]
# ### Spiders

# %%
# Figure mean ( derot(IM1-IM2) + derot(IM2-IM1) )
for i in range(5,6):
    fn = FNs_MASK[i]
    im = MASKs[i] ; print(np.shape(im))
    text = LABELs[i]
    namesave = fn

    vmin, vmax = 0, 1
    
    fig, ax = plot_fig(im=im, clab=clab, vmin=vmin, vmax=vmax, figsize=figsize,
             im_crop=im_crop, saving_dir=saving_dir, namesave=namesave,
             add_colorbar=0, do_tight_layout=0, scalebar_color=scalebar_color,
            scalebar_arcsec=scalebar_arcsec, scalebar_leg=scalebar_leg, scalebar_label_top=False, 
            scalebar_sep= scalebar_sep, scalebar_pad= scalebar_pad, cmap=cmap,
            platescale=platescale, return_fig_ax=True, 
            #right=right
            )
    
    ax.text(scalebar_xtext, scalebar_ytext, scalebar_text, transform=ax.transAxes, color=scalebar_color)
    
    ax.text(xtext, ytext, text, transform=ax.transAxes, color='grey')
    
    plt.savefig(saving_dir+namesave+'.pdf',dpi=200)
# Out:
# (296, 296)

# %% [markdown]
# #### for each rolling angle

# %%
# Figure mean ( derot(IM1-IM2) + derot(IM2-IM1) )
for i in range(6,7):
    fn = FNs_MASK[i]
    cube = MASKs[i] ; print(np.shape(im))
    for j in range(len(cube)):
        im = cube[j]
        text = LABELs[i][j]
        namesave = fn+str(j)

        vmin, vmax = 0, 1
    
        fig, ax = plot_fig(im=im, clab=clab, vmin=vmin, vmax=vmax, figsize = figsize, 
            im_crop=im_crop, saving_dir=saving_dir, namesave=namesave,
             add_colorbar=0, do_tight_layout=0, scalebar_color=scalebar_color,
            scalebar_arcsec=scalebar_arcsec, scalebar_leg=scalebar_leg, scalebar_label_top=False, 
            scalebar_sep=scalebar_sep, scalebar_pad = scalebar_pad, cmap=cmap,
            platescale=platescale, return_fig_ax=True, 
            #right=right
            )
        
        ax.text(scalebar_xtext, scalebar_ytext, scalebar_text, transform=ax.transAxes, color=scalebar_color)
        ax.text(xtext, ytext, text, transform=ax.transAxes, color=scalebar_color)
    
        if j == 0 or j: ax.text(xtext, ytext, text, transform=ax.transAxes, color='grey')
        
        plt.savefig(saving_dir+namesave+'.pdf',dpi=200)
# Out:
# (296, 296)

# %% [markdown]
# #### combine

# %%
# Figure mean ( derot(IM1-IM2) + derot(IM2-IM1) )
for i in range(7,10):
    fn = FNs_MASK[i]
    im = MASKs[i] ; print(np.shape(im))
    text = LABELs[i]
    namesave = fn

    vmin, vmax = 0, None
    
    fig, ax = plot_fig(im=im, clab=clab, vmin=vmin, vmax=vmax, figsize=figsize,
             im_crop=im_crop, saving_dir=saving_dir, namesave=namesave,
             add_colorbar=0, do_tight_layout=0, scalebar_color=scalebar_color,
            scalebar_arcsec=scalebar_arcsec, scalebar_leg=scalebar_leg, scalebar_label_top=False, 
            scalebar_sep= scalebar_sep, scalebar_pad= scalebar_pad, cmap=cmap,
            platescale=platescale, return_fig_ax=True, 
            #right=right
            )
    
    ax.text(scalebar_xtext, scalebar_ytext, scalebar_text, transform=ax.transAxes, color=scalebar_color)
    
    if 'gradient' in text: bonus=-0.08
    else: bonus=0
    ax.text(xtext, ytext+bonus, text, transform=ax.transAxes, color=scalebar_color)
    if 'occult' in text: ax.text(xtext, ytext, text, transform=ax.transAxes, color='grey')
   
    
    plt.savefig(saving_dir+namesave+'.pdf',dpi=200)
# Out:
# (296, 296)
# (296, 296)
# (296, 296)

# %% [markdown]
# ### Mask + spiders

# %%
# Figure mean ( derot(IM1-IM2) + derot(IM2-IM1) )
for i in range(10,11):
    fn = FNs_MASK[i]
    im = MASKs[i] ; print(np.shape(im))
    text = LABELs[i]
    namesave = fn

    vmin, vmax = 0, None
    
    fig, ax = plot_fig(im=im, clab=clab, vmin=vmin, vmax=vmax, figsize=figsize,
             im_crop=im_crop, saving_dir=saving_dir, namesave=namesave,
             add_colorbar=0, do_tight_layout=0, scalebar_color=scalebar_color,
            scalebar_arcsec=scalebar_arcsec, scalebar_leg=scalebar_leg, scalebar_label_top=False, 
            scalebar_sep= scalebar_sep, scalebar_pad= scalebar_pad, cmap=cmap,
            platescale=platescale, return_fig_ax=True, 
            #right=right
            )
    
    ax.text(scalebar_xtext, scalebar_ytext, scalebar_text, transform=ax.transAxes, color=scalebar_color)
    
    ax.text(xtext, ytext, text, transform=ax.transAxes, color=scalebar_color)
    
    plt.savefig(saving_dir+namesave+'.pdf',dpi=200)
# Out:
# (296, 296)

# %% [markdown]
# #### for each rolling angle

# %%
# Figure mean ( derot(IM1-IM2) + derot(IM2-IM1) )
for i in range(11,12):
    fn = FNs_MASK[i]
    cube = MASKs[i] ; print(np.shape(im))
    for j in range(len(cube)):
        im = cube[j]
        text = LABELs[i][j]
        namesave = fn+str(j)

        vmin, vmax = 0, 1
    
        fig, ax = plot_fig(im=im, clab=clab, vmin=vmin, vmax=vmax, figsize = figsize, 
            im_crop=im_crop, saving_dir=saving_dir, namesave=namesave,
             add_colorbar=0, do_tight_layout=0, scalebar_color=scalebar_color,
            scalebar_arcsec=scalebar_arcsec, scalebar_leg=scalebar_leg, scalebar_label_top=False, 
            scalebar_sep=scalebar_sep, scalebar_pad = scalebar_pad, cmap=cmap,
            platescale=platescale, return_fig_ax=True, 
            #right=right
            )
        
        ax.text(scalebar_xtext, scalebar_ytext, scalebar_text, transform=ax.transAxes, color=scalebar_color)
        ax.text(xtext, ytext, text, transform=ax.transAxes, color=scalebar_color)
    
        if j == 0 or j: ax.text(xtext, ytext, text, transform=ax.transAxes, color='grey')
        
        plt.savefig(saving_dir+namesave+'.pdf',dpi=200)
# Out:
# (296, 296)

# %% [markdown]
# #### combine

# %%
# Figure mean ( derot(IM1-IM2) + derot(IM2-IM1) )
for i in range(12,15):
    fn = FNs_MASK[i]
    im = MASKs[i] ; print(np.shape(im))
    text = LABELs[i]
    namesave = fn

    vmin, vmax = 0, None
    
    fig, ax = plot_fig(im=im, clab=clab, vmin=vmin, vmax=vmax, figsize=figsize,
             im_crop=im_crop, saving_dir=saving_dir, namesave=namesave,
             add_colorbar=0, do_tight_layout=0, scalebar_color=scalebar_color,
            scalebar_arcsec=scalebar_arcsec, scalebar_leg=scalebar_leg, scalebar_label_top=False, 
            scalebar_sep= scalebar_sep, scalebar_pad= scalebar_pad, cmap=cmap,
            platescale=platescale, return_fig_ax=True, 
            #right=right
            )
    
    ax.text(scalebar_xtext, scalebar_ytext, scalebar_text, transform=ax.transAxes, color=scalebar_color)
    
    if 'mask+spiders' in text: bonus=-0.08
    else: bonus=0
    
    if 'occult' in text: ax.text(xtext, ytext+bonus, text, transform=ax.transAxes, color='grey')
    else: ax.text(xtext, ytext+bonus, text, transform=ax.transAxes, color=scalebar_color)
   
    
    plt.savefig(saving_dir+namesave+'.pdf',dpi=200)
# Out:
# (296, 296)
# (296, 296)
# (296, 296)

# %% [markdown]
# ## Plot the composite image

# %%
folder_composite = 'results/composite/HST_IM12_and_SPHERE'
folder_composite = 'results/composite/HST_IM12_mask+spiders_and_SPHERE'

# %%
FNs = ['im_composite_HST_IRDIS_polar', 'im_composite_HST_IRDIS_ti'
        ]
LABELs = ['SPHERE-IRDIS (polar)', 'SPHERE-IRDIS (tot. intensity)'
         ]
IMs = [ fits.getdata( '{}/{}.fits'.format(folder_composite, fn)) for fn in FNs]

im_crop_composite = 100
scalebar_color = 'white'

# %%
#im[714:788, 664:838]/np.nanmax()

# %%
# Figure mean ( derot(IM1-IM2) + derot(IM2-IM1) )
for i in range(2):
    fn = FNs[i]
    im = np.copy(IMs[i]) ; print(np.shape(im))
    text = LABELs[i]
    namesave = fn
    
    fits.writeto(saving_dir+'test'+text+'.fits', im, overwrite=True)
    
    fact=1.5
    im[:714, :]= np.abs(im[:714, :])*fact
    im[788:, :]= np.abs(im[788:, :])*fact
    im[:, :664]= np.abs(im[:, :664])*fact
    im[:, 838:]= np.abs(im[:, 838:])*fact
    
    
    crop_height=300; bonus_top = 200
    im = im[ crop_height:-crop_height-bonus_top, :]
    
    vminmax = 1
    
    vmin, vmax = -vminmax, vminmax
    
    im_crop_composite=100
    scalebar_pad_composite=scalebar_pad

    fig, ax = plot_fig(im=im, clab=clab, vmin=vmin, vmax=vmax, figsize=(6,3.5), 
             im_crop=im_crop_composite, saving_dir=saving_dir, namesave=namesave,
             add_colorbar=0, do_tight_layout=0, scalebar_color=scalebar_color,
            scalebar_arcsec=scalebar_arcsec, scalebar_leg=scalebar_leg, scalebar_label_top=False, 
            scalebar_sep= scalebar_sep, scalebar_pad= scalebar_pad_composite, cmap=cmap,
            platescale=platescale_composite, return_fig_ax=True, 
            #right=right
            )
    
    w, h = np.shape(im)[1]-im_crop_composite*2, np.shape(im)[0]-im_crop_composite*2
    xc, yc =  w/2, h/2+bonus_top/2
    ax.plot(xc, yc, marker='*', ms=8, color='yellow', zorder=1)
    fig.subplots_adjust(left=0.01, right=0.99, bottom=0.01, top=0.99)
    ax.set_xlim([0,w]);  ax.set_ylim([0,h])
    
    
    if 1:
        ax.text(scalebar_xtext+0.02, scalebar_ytext+0.03, scalebar_text, transform=ax.transAxes, color=scalebar_color)
        bonus= 0.2
        xtext, ytext = 0.02, 0.9
        ax.text(xtext, ytext, 'HST-STIS +', transform=ax.transAxes, color=scalebar_color)
        ax.text(xtext+bonus, ytext, text, transform=ax.transAxes, color=[0.9,0,0.9])

    plt.savefig(saving_dir+namesave+'.pdf',dpi=200)
# Out:
# (1503, 1503)
# (1503, 1503)

# %%
platescale_composite = 10e-3

# %%
scalebar_arcsec
# Out:
# 2

# %%
# load specific stuff for synthethic population models
n_colors = 5
#list_colors = ['black', 'gray', [0.8,0.9,1]]
list_colors = ['orange', 'hotpink', [0.9,0,0.9], 'purple', 'black', [0.5,0.5,0.5], [0.7,0.7,0.7], [0.9,0.9,0.9], 'white']
palette,cmap,COLORS = define_color_shades(list_colors, n_colors, show=0, blend=True)

# cmaps
cmap =  seaborn.blend_palette(list_colors , as_cmap=True)
display(cmap)

# %% [markdown]
# # Test

# %%
fn_mask = 'mask+spiders_cube_rot'
mask = fits.getdata( '{}/{}.fits'.format(folder, fn_mask))
mask[mask>0.5]=1
mask = mask.astype(int)

# %%
im4 = IMs[4]

# %%
im1 = mask[0]*IMs[4]
im2 = mask[1]*IMs[5]
im1_hidden_im2 =  np.where(mask[1]==0, IMs[4], 0)
im2_hidden_im1 =  np.where(mask[0]==0, IMs[5], 0)
im = np.nanmean([im1,im2], axis=0) + im1_hidden_im2 + im2_hidden_im1

# %%
test = np.array([[0,1], [0,0]])
M = np.array([[1,2],[3,4]])
#M[test]
np.where(test, M, 0)
# Out:
# array([[0, 2],
#        [0, 0]])

# %%
fits.writeto('IM_cadi_derot_smart2.fits',im)

# %%
FNs
# Out:
# ['IM1_ORIENT1',
#  'IM2_ORIENT2',
#  'IM1_derot',
#  'IM2_derot',
#  'IM12_derot',
#  'IM21_derot',
#  'IM_cadi_derot',
#  'im_obs_mask_min_final',
#  'im_obs_mask_max_final']

# %% [markdown]
# ### Mask

# %%
# Figure mean ( derot(IM1-IM2) + derot(IM2-IM1) )
for i in range(1):
    fn = fn_mask
    #im = mask[0]*IMs[4] ; print(np.shape(im))
    namesave = fn

    vmin, vmax = 0,  50
    
    fig, ax = plot_fig(im=im, clab=clab, vmin=vmin, vmax=vmax, 
             im_crop=im_crop, saving_dir=saving_dir, namesave=namesave,
             add_colorbar=0, do_tight_layout=0,
            scalebar_arcsec=scalebar_arcsec, scalebar_leg=scalebar_leg, scalebar_label_top=False, scalebar_sep=6,
            platescale=platescale, return_fig_ax=True,
            #right=right
            )
    
    ax.text(scalebar_xtext, scalebar_ytext, scalebar_text, transform=ax.transAxes, color='white')
    
    plt.savefig(saving_dir+fn+'.pdf',dpi=200)
