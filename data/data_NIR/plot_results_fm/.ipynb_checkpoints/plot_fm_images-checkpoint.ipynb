# %% [markdown]
# _Written by Célia Desgrange, 2022-12-13.
# _Revised by Célia:_
#
#
# SHOULD COPY THIS LINE IN ALL FM RESULTS BASED ON JOINT-FITTING
#
# scalebar_pad=scalebar_pad, scalebar_sep=scalebar_sep, add_scalebar_au=1, scalebar_au=scalebar_au, add_IWA=0,

# %%
import glob
import numpy as np
import time, os

#from astropy.convolution import (convolve_fft, convolve, Gaussian2DKernel)

#import vip_hci as vip
#from astropy.io import fits
#import cv2 

from import_functions_generic import * 
from import_functions_plotting import * 
#from image_manipulation import *

# %%
plt.style.use('classic')  
mpl.rc('image', cmap='viridis')#, origin='lower')
#mpl.rc('text', usetex=True)
#mpl.rc(mathtext.fontset = 'stix')


rcParams.update({'font.size': 14,  'axes.labelsize' : 14, 'legend.fontsize' : 12,
"font.family": "serif", 'text.usetex' : True, "font.serif": [], "font.sans-serif": [],
'legend.handlelength': 1.5, 'legend.borderaxespad' : 0.8, 'legend.columnspacing' : 1, 'legend.handletextpad' : 0.5})

rcParams['mathtext.fontset'] = 'stix'

# %%
L = time.localtime()
date = "{}-{}-{}".format(L[0],L[1],L[2],L[3],L[4],L[5])

saving_dir = 'figs/fig_v{}/'.format(date)
os.makedirs(saving_dir,exist_ok=True)

# %%
help(plot_fig)
# Out:
# Help on function plot_fig in module import_functions_plotting:
#
# plot_fig(im, clab='', vmin=None, vmax=None, text='None', text_xfrac=0.03, text_yfrac=0.9, color_text='white', add_text=0, show_axis_ticks='off', im_crop=0, platescale_use_binning_factor=0, binning_factor=None, flux_use_binning_factor=0, scalebar_arcsec=0.1, scalebar_leg='0.1"', scalebar_loc=3, platescale=12.25, scalebar_color='white', scalebar_pad=0.4, scalebar_sep=2, scalebar_borderpad=0.5, scalebar_label_top=True, add_colorbar=1, cbar_xdeb=0.82, cbar_ydeb=0.1, cbar_xwidth=0.03, cbar_ywidth=0.8, right=0.8, top=0.95, left=0.01, bottom=0.05, figsize=(5, 4), interpolation='nearest', saving_dir='', namesave='test', save_png=0, cmap='magma', norm=None, do_tight_layout=1, return_fig_ax=False, give_fig_ax=False, fig=None, ax=None, show=1)

# %% [markdown]
# # I. Load an observation

# %%
# Initialize the path to the wished data 
# -> supposed to be changed accordingly to the data/computer used
infolder = '/Users/desgranc/Documents/work/projects/HD120326/data/'
folder_prereduced = 'prereduced/convert/'
folder_reduced = 'reduced/'
dF       = pd.read_csv(infolder + 'list_obs.txt',sep='\t')
dF
# Out:
#       target       epoch instrument polar filter    quality seeing (")  \
# 0  HD_120326  2016-04-05      IRDIS    no    H23       good        1.1
# 1  HD_120326  2016-06-03      IRDIS    no    H23       good       0.71
# 2  HD_120326  2016-06-13      IRDIS    no    J23   to check   to check
# 3  HD_120326  2018-06-01      IRDIS   yes   BB_H  very good       0.45
# 4  HD_120326  2019-06-26      IRDIS    no   BB_H   very bad       1.84
# 5  HD_120326  2019-07-09      IRDIS    no   BB_H  very good       0.54
# 6  HD_120326  2016-04-05        IFS    no     YJ       good        1.1
# 7  HD_120326  2016-06-03        IFS    no     YJ       good       0.71
# 8  HD_120326  2019-06-26        IFS    no     YJ   very bad       1.84
# 9  HD_120326  2019-07-09        IFS    no     YJ  very good       0.54
#
#   tau0 (ms) delta pa (deg)                  PI  DIT (s)  Nb frames  \
# 0       3.5             37   Bonnefoy & Ménard     32.0      128.0
# ...

# %%
idx, idx_pcs, before_or_after,sorting = 9, 10, 'before','sorting' #'softsorting'
epoch = str(dF['epoch'].iloc[idx])
filt =  str(dF['filter'].iloc[idx])
print('Load the epoch: {}'.format(epoch))
algo = 'PCA_Celia/fits/SCIENCE/'

path_im_reduced = infolder + folder_reduced + algo + '*{}*{}*{}_cube_im_pca.fits'.format(epoch,before_or_after,sorting)
obs_polar = str(dF['polar'].iloc[idx])
if obs_polar == 'yes': 
    print('(!) polarized light')
    algo = 'IRDAP/'
    path_im_reduced = infolder + folder_reduced + algo + '{}/reduced_pdi/star_pol*/*Q_phi*.fits'.format(epoch)
        
print('It corresponds do the path:\n{}'.format(path_im_reduced))
print('\nFiles found:')
flist = glob(path_im_reduced)
for f in flist: print('-',f)
im_reduced = fits.getdata(flist[1])[idx_pcs]
# Out:
# Load the epoch: 2019-07-09
# It corresponds do the path:
# /Users/desgranc/Documents/work/projects/HD120326/data/reduced/PCA_Celia/fits/SCIENCE/*2019-07-09*before*sorting_cube_im_pca.fits
#
# Files found:
# - /Users/desgranc/Documents/work/projects/HD120326/data/reduced/PCA_Celia/fits/SCIENCE/2019-07-09_IFS_J_20-38_both_channels_combine_before_Nonesorting_cube_im_pca.fits
# - /Users/desgranc/Documents/work/projects/HD120326/data/reduced/PCA_Celia/fits/SCIENCE/2019-07-09_IFS_Y_2-17_both_channels_combine_before_Nonesorting_cube_im_pca.fits

# %% [markdown]
# # General parameters

# %%
# Image - observation
pixel_scale=0.01225 # pixel scale in arcsec/px 
pixel_scale=0.00746
platescale = pixel_scale*1e3
scalebar_pix, scalebar_leg = 1000, '1"'
nx = 624 # number of pixels of your image in X
ny = 624 # number of pixels of your image in Y

# Save file .fits
writeto = False # save .fits file

# Figure
add_colorbar=0
figsize_rectange, figsize_square  = (4,3), (3,3)
figsize = np.where(add_colorbar, figsize_rectange, figsize_square)
left, right = 0.01, float(np.where(add_colorbar, 0.78, 0.99))
top, bottom = float(np.where(add_colorbar, 0.95, 0.99)), float(np.where(add_colorbar, 0.05, 0.01))
im_crop = 250
save_png = 0    # save .png file
cbar_xdeb = 0.83
scalebar_pix, scalebar_leg = 100, '0.1"'

text_xfrac, text_yfrac = 0.03, 0.84
filt='H'

# System
dstar = 113.27
scalebar_au = '{:.0f}\,au'.format(dstar*scalebar_pix*1e-3)
scalebar_sep, scalebar_pad = 5, 0.1

# %%
# load specific stuff for synthethic population models
param = 'literature/'
model = 'cond2003/'
data = '/RV+DI_all_epochs_ird/'

# cmaps
cmap_dark_red =  seaborn.blend_palette([[1,0,0],'crimson','firebrick','darkred',[0.3,0,0]], as_cmap=True)
cmap_red = seaborn.blend_palette(['white',[1,0.95,0],'orange', 'red'], as_cmap=True)
cmap_orange = seaborn.blend_palette(['white',[1,0.95,0],'gold'], as_cmap=True)
cmap_pinkish = seaborn.blend_palette(['white',[1,0.5,1],'purple', 'blue'], as_cmap=True)
cmap_pink = seaborn.blend_palette(['white',[1,0.4,1],[0.8,0,0.7],[0.75,0,0.7]], as_cmap=True)
cmap_blue = seaborn.blend_palette(['white',[0.5,0.9,1], [0,0.5,1],  [0,0,1]], as_cmap=True)
cmap_blue_light = seaborn.blend_palette(['white',[0.5,0.9,1], [0,0.5,1]], as_cmap=True)
cmap_white = seaborn.blend_palette(['white', 'ivory'], as_cmap=True)

display(cmap_white)

cmap = cmap_white

# %% [markdown]
# # I. Plot images with polarimetric model contours

# %%
fn = '/Users/desgranc/Documents/work/GitHub_clone/projects/HD102326/fm/results/results_polar/2023-3-30-8h40min57s/results_AMOEBA/best_modelconvolved_amoeba.fits'
epoch = '2018-06-01'
im_model = fits.getdata(fn)

# %%
namesave = 'disk_model_{}'.format( epoch)
im = np.copy(im_model)
im_crop_model = 0#12
im_crop = im_crop_model

print('Size of the image =', len(im), 'and crop =', im_crop, 
      'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = 'contrast'
vmin, vmax = 0, 40

text = '{} {}\n model'.format(epoch, filt, algo)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, 
         scalebar_arcsec=scalebar_pix, scalebar_leg=scalebar_leg, 
         platescale=platescale, figsize=figsize,
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac,
         right=right, left=left, top=top, bottom=bottom,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 124 and crop = 0 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-9-12/disk_model_2018-06-01

# %% [markdown]
# ## 1. Add contours on the model image (polar)

# %%
namesave = 'im_model_{}_contours'.format(epoch)
im = np.copy(im_model)
im_crop_model = 0
im_crop = im_crop_model
n_final = len(im)-2*im_crop

print('Size of the image =', len(im), 'and crop =', im_crop, 
      'i.e. size of the image shown =',  n_final)

clab = 'contrast'
vmin, vmax = 0, 40

text = '{} {}\nmodel'.format(epoch, filt, algo)


fig, ax = plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, 
         scalebar_arcsec=scalebar_pix, scalebar_leg=scalebar_leg, 
         platescale=platescale, figsize=figsize,
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac,
         right=right, left=left, top=top, bottom=bottom,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave,
        give_fig_ax=False, return_fig_ax=True)

## Add contours
lvl_contours = [10]

#im[im<0]=0
#imc = im[im_crop:-im_crop,im_crop:-im_crop]
imc = im_model
XX, YY = np.arange(n_final), np.arange(n_final)
contours = ax.contour(XX, YY, imc, lvl_contours, cmap=cmap)
#ax.clabel(contours, inline=True)

print('The file is saved here:\n', saving_dir+namesave)
plt.savefig(saving_dir+namesave+'.pdf')
if save_png: plt.savefig(saving_dir+namesave+'.png', dpi=200)
plt.show()
# Out:
# Size of the image = 124 and crop = 0 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-9-12/im_model_2018-06-01_contours

# %% [markdown]
# ## 2. Add contours on the reduced IRDAP image (polar)

# %%
namesave = 'im_obs_reduced_{}_contours'.format( epoch)
im = np.copy(im_reduced)
im_crop_IRDAP = 60#450
im_crop = im_crop_IRDAP
n_final = len(im)-2*im_crop

print('Size of the image =', len(im), 'and crop =', im_crop, 
      'i.e. size of the image shown =',  n_final)

clab = 'contrast'
vmin, vmax = 0, 40

text = '{} {}\n{}'.format(epoch, filt, algo)
text = '{} {} (polar)\n{}'.format(epoch, filt, algo)

fig, ax = plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, 
         scalebar_arcsec=scalebar_pix, scalebar_leg=scalebar_leg, 
         platescale=platescale, figsize=figsize,
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac,
         right=right, left=left, top=top, bottom=bottom,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave,
        give_fig_ax=False, return_fig_ax=True) 


## Add contours
lvl_contours = [10]

#im[im<0]=0
#imc = im[im_crop:-im_crop,im_crop:-im_crop]
imc = im_model
XX, YY = np.arange(n_final), np.arange(n_final)
contours = ax.contour(XX, YY, imc, lvl_contours, cmap=cmap)
#ax.clabel(contours, inline=True)

print('The file is saved here:\n', saving_dir+namesave)
plt.savefig(saving_dir+namesave+'.pdf')
if save_png: plt.savefig(saving_dir+namesave+'.png', dpi=200)
plt.show()

# %% [markdown]
# ## 3. Add contours on the reduced total intensity image (2019-07-09)

# %%
namesave = 'im_obs_reduced_pca_{}_{}ncomp_contours'.format(epoch, idx_pcs+1)
im = np.copy(im_reduced)
im_crop_PCA = 250
im_crop = im_crop_PCA

print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = 'contrast'
vmin, vmax = None, None
text = '{} {}\n{}'.format(epoch, filt, algo)
text = '{} {} (total intensity) \n{}'.format(epoch, filt.replace('BB',''), algo)

fig, ax = plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave,
         return_fig_ax=True)

## Add contours
lvl_contours = [10]

#im[im<0]=0
#imc = im[im_crop:-im_crop,im_crop:-im_crop]
imc = im_model
XX, YY = np.arange(n_final), np.arange(n_final)
contours = ax.contour(XX, YY, imc, lvl_contours, cmap=cmap)
#ax.clabel(contours, inline=True)

print('The file is saved here:\n', saving_dir+namesave)
plt.savefig(saving_dir+namesave+'.pdf')
if save_png: plt.savefig(saving_dir+namesave+'.png', dpi=200)
plt.show()
# Out:
# Size of the image = 624 and crop PCA = 250 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-6-16/im_obs_reduced_pca_2019-07-09_10ncomp_contours

# %% [markdown]
# # II. Plot images resulting from the disk modelling

# %%
infolder_results_model = '/Users/desgranc/Documents/work/GitHub_clone/projects/HD102326/fm/results/'

# %% [markdown]
# ## 1. Independent fit
#
# ### IRDIS 2018-06-01 BBH

# %%
epoch, filt = '2018-06-01', 'H'
folder = 'results_polar/' #'results_{}_{}/'.format(filt, epoch)
subfolder = 'amoeba_final/'
fn_model = 'disk_model_convolved.fits'
fn_res = 'residuals_fm_snr.fits'

# %%
config = '2023-6-19-11h36min3s/' #'2023-6-19-11h33min48s/'

path_res = infolder_results_model+folder+config+subfolder+fn_res
path_model = infolder_results_model+folder+config+subfolder+fn_model

# %%
im = fits.getdata(path_res)

namesave = '{}_res'.format(epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = -7,7
text = '{} {} (polar)\nResiduals'.format(epoch,filt)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize,do_tight_layout=0,
         scalebar_arcsec=scalebar_pix, scalebar_leg=scalebar_leg, 
        scalebar_pad=scalebar_pad, scalebar_sep=scalebar_sep, add_scalebar_au=1, scalebar_au=scalebar_au, add_IWA=1,
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.02,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-9-12/2018-06-01_res

# %%
im = fits.getdata(path_model)

namesave = '{}_model'.format(epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = 0, 30
text = '{} {} (polar)\nModel (linear scale)'.format(epoch,filt)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_arcsec=scalebar_pix, scalebar_leg=scalebar_leg, 
         scalebar_pad=scalebar_pad, scalebar_sep=scalebar_sep, add_scalebar_au=1, scalebar_au=scalebar_au, add_IWA=0,
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.02,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-9-12/2018-06-01_model

# %% [markdown]
# ### IRDIS 2019-07-09 BBH

# %%
epoch, filt = '2019-07-09', 'BBH'
folder = 'results_{}_{}/'.format(filt, epoch)
subfolder = 'amoeba_final/'
fn_model = 'disk_model_convolved.fits'
fn_res = 'residuals_fm.fits'
fn_red_im = 'inputs/reduced_image.fits'

filt = filt.replace('BB','')

# %% [markdown]
# #### 5 params 10 modes

# %%
#config = '2023-4-12-9h55min30s_5params_5modes_maskrad7pix/'
config = '2023-4-13-8h2min7s_5params_10modes_maskrad7pix/'
#config = '2023-4-13-8h4min30s_5params_5modes_maskrad7pix_combined_before_processing/'
config = '2023-4-13-8h3min56s_5params_10modes_maskrad7pix_combined_before_processing/'

path_res = infolder_results_model+folder+config+subfolder+fn_res
path_model = infolder_results_model+folder+config+subfolder+fn_model
path_input = infolder_results_model+folder+config+fn_red_im

nparams = select_string_between_characs(config,'_','p',0)
nmodes = select_string_between_characs(config,'_','m',1)
if 'combined' in config: nbands='1+2'
else: nbands='1'
print('Number of modes:', nmodes)
print('Number of params:', nparams)
print('Number of bands:', nbands)
# Out:
# Number of modes: 10
# Number of params: 5
# Number of bands: 1+2

# %% [markdown]
# ### Residuals

# %%
im = fits.getdata(path_res)

namesave = '{}_{}modes_{}_res'.format(epoch,nmodes,nbands)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = -2, 2
#text = '{0} {1} (channel {})\nPCA ({3} modes) \nResiduals'.format(epoch,filt,nbands,nmodes)
#text = '{0} {1} (total intensity)\nPCA ({3} modes) \nResiduals'.format(epoch,filt,nbands,nmodes)
text = '{0} {1} (total intensity)\nResiduals\n'.format(epoch,filt,nbands,nmodes)

#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_arcsec=scalebar_pix, scalebar_leg=scalebar_leg, 
         scalebar_pad=scalebar_pad, scalebar_sep=scalebar_sep, add_scalebar_au=1, scalebar_au=scalebar_au,
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-9-12/2019-07-09_10modes_1+2_res

# %% [markdown]
# ### Synthetic models

# %%
im = fits.getdata(path_model)

namesave = '{}_{}modes_{}_model_log'.format(epoch,nmodes,nbands)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
#im = im / np.nanmax(im)
#im = np.log10(im)
#im [im<0]=0
vmin, vmax = 0, np.nanmax(im) 
print(np.nanmin(im), np.nanmax(im))
norm = colors.LogNorm(vmin=1e-2, vmax=vmax, clip=True)
#text = '{} {} (channel {})\nPCA ({} modes) \nModel'.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = '{0} {1} (total intensity) \nModel (log scale)'.format(epoch,filt,nbands,nmodes)

plot_fig(im=im, #vmin=vmin, vmax=vmax, 
         im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_arcsec=scalebar_pix, scalebar_leg=scalebar_leg, norm=norm,
         scalebar_pad=scalebar_pad, scalebar_sep=scalebar_sep, add_scalebar_au=1, scalebar_au=scalebar_au, add_IWA=0,
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.0,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# -1.2836259832837982e-15 72.76452881606342
# The file is saved here:
#  figs/fig_v2023-9-12/2019-07-09_10modes_1+2_model_log

# %% [markdown]
# ### Reduce imaged

# %%
im = fits.getdata(path_input)

namesave = '{}_{}modes_{}_obs'.format(epoch,nmodes,nbands)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = -2, 2
#text = '{} {} (channel {})\nPCA ({} modes) \nObs '.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = '{0} {1} (total intensity)\nPCA ({3} modes) \nObs'.format(epoch,filt,nbands,nmodes)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_arcsec=scalebar_pix, scalebar_leg=scalebar_leg, 
         scalebar_pad=scalebar_pad, scalebar_sep=scalebar_sep, add_scalebar_au=1, scalebar_au=scalebar_au, add_IWA=0,
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-9-12/2019-07-09_10modes_1+2_obs

# %% [markdown]
# ### IRDIS 2016-04-05 H23

# %%
epoch, filt = '2016-04-05', 'H23'
folder = 'results_{}_{}/'.format(filt, epoch)
subfolder = 'amoeba_final/'
fn_model = 'disk_model_convolved.fits'
fn_res = 'residuals_fm.fits'
fn_red_im = 'inputs/reduced_image.fits'

filt = filt.replace('BB','')

# %%
#config = '2023-4-12-9h56min37s_5params_5modes/'
#config = '2023-4-12-10h49min1s_5params_10modes/'
#config = '2023-4-13-7h59min1s_5params_5modes_combined_before/'
config = '2023-4-12-19h18min53s_5params_10modes_combined_before/'

path_res = infolder_results_model+folder+config+subfolder+fn_res
path_model = infolder_results_model+folder+config+subfolder+fn_model
path_input = infolder_results_model+folder+config+fn_red_im

nparams = select_string_between_characs(config,'_','p',0)
nmodes = select_string_between_characs(config,'_','m',1)
if 'combined' in config: nbands='1+2'
else: nbands='1'
print('Number of modes:', nmodes)
print('Number of params:', nparams)
print('Number of bands:', nbands)
# Out:
# Number of modes: 10
# Number of params: 5
# Number of bands: 1+2

# %% [markdown]
# ### Residuals

# %%
im = fits.getdata(path_res)

namesave = '{}_{}modes_{}_res'.format(epoch,nmodes,nbands)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = -0.5, 0.5
#text = '{0} {1} (channel {})\nPCA ({3} modes) \nResiduals'.format(epoch,filt,nbands,nmodes)
#text = '{0} {1} (total intensity)\nPCA ({3} modes) \nResiduals'.format(epoch,filt,nbands,nmodes)
text = '{0} {1} (total intensity)\nResiduals\n'.format(epoch,filt,nbands,nmodes)

#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_arcsec=scalebar_pix, scalebar_leg=scalebar_leg, 
        scalebar_pad=scalebar_pad, scalebar_sep=scalebar_sep, add_scalebar_au=1, scalebar_au=scalebar_au, add_IWA=1,
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)

# Add scale bar au
ax.text(text_xfrac*0.8,0.155, scalebar_au, color='white', transform=ax.transAxes)

# Add IWA
h, w = n_final, n_final
r_IWA = 100
IWA_color = [0.8,0.8,0.8]
circle = Circle((h/2,w/2),r_IWA/platescale,ec=IWA_color,fc=IWA_color,ls='-',lw=1)
ax.add_patch(circle)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-9-12/2016-04-05_10modes_1+2_res

# %% [markdown]
# ### Synthetic model

# %%
im = fits.getdata(path_model)

namesave = '{}_{}modes_{}_model_log'.format(epoch,nmodes,nbands)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
#im = im / np.nanmax(im)
#im = np.log10(im)
#im [im<0]=0
vmin, vmax = 0, np.nanmax(im) 
print(np.nanmin(im), np.nanmax(im))
norm = colors.LogNorm(vmin=1e-2, vmax=vmax, clip=True)
#text = '{} {} (channel {})\nPCA ({} modes) \nModel'.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = '{0} {1} (total intensity) \nModel (log scale)'.format(epoch,filt,nbands,nmodes)

plot_fig(im=im, #vmin=vmin, vmax=vmax, 
         im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_arcsec=scalebar_pix, scalebar_leg=scalebar_leg, norm=norm,
        scalebar_pad=scalebar_pad, scalebar_sep=scalebar_sep, add_scalebar_au=1, scalebar_au=scalebar_au, add_IWA=0,
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.0,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# -3.250177904590146e-16 18.46243336418004
# The file is saved here:
#  figs/fig_v2023-9-12/2016-04-05_10modes_1+2_model_log

# %% [markdown]
# ### IRDIS 2016-06-03 H23

# %%
epoch, filt = '2016-06-03', 'H23'
folder = 'results_{}_{}/'.format(filt, epoch)
subfolder = 'amoeba_final/'
fn_model = 'disk_model_convolved.fits'
fn_res = 'residuals_fm.fits'
fn_red_im = 'inputs/reduced_image.fits'

filt = filt.replace('BB','')

# %%
#config = '2023-4-12-9h58min10s_5params_5modes/'
#config = '2023-4-12-15h43min5s_5params_10modes/'
#config = '2023-4-13-7h59min4s_5params_5modes_combined_before/'
config = '2023-4-13-10h46min59s_5params_10modes_combined_before/'

path_res = infolder_results_model+folder+config+subfolder+fn_res
path_model = infolder_results_model+folder+config+subfolder+fn_model
path_input = infolder_results_model+folder+config+fn_red_im

nparams = select_string_between_characs(config,'_','p',0)
nmodes = select_string_between_characs(config,'_','m',1)
if 'combined' in config: nbands='1+2'
else: nbands='1'
print('Number of modes:', nmodes)
print('Number of params:', nparams)
print('Number of bands:', nbands)
# Out:
# Number of modes: 10
# Number of params: 5
# Number of bands: 1+2

# %% [markdown]
# ### Residuals

# %%
im = fits.getdata(path_res)

namesave = '{}_{}modes_{}_res'.format(epoch,nmodes,nbands)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = -0.5, 0.5
#text = '{0} {1} (channel {})\nPCA ({3} modes) \nResiduals'.format(epoch,filt,nbands,nmodes)
#text = '{0} {1} (total intensity)\nPCA ({3} modes) \nResiduals'.format(epoch,filt,nbands,nmodes)
text = '{0} {1} (total intensity)\nResiduals\n'.format(epoch,filt,nbands,nmodes)

#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)



plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_arcsec=scalebar_pix, scalebar_leg=scalebar_leg, 
         scalebar_pad=scalebar_pad, scalebar_sep=scalebar_sep, add_scalebar_au=1, scalebar_au=scalebar_au, add_IWA=1,
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-9-12/2016-06-03_10modes_1+2_res

# %% [markdown]
# ### Synthetic model

# %%
im = fits.getdata(path_model)

namesave = '{}_{}modes_{}_model_log'.format(epoch,nmodes,nbands)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
#im = im / np.nanmax(im)
#im = np.log10(im)
#im [im<0]=0
vmin, vmax = 0, np.nanmax(im) 
print(np.nanmin(im), np.nanmax(im))
norm = colors.LogNorm(vmin=1e-2, vmax=vmax, clip=True)
#text = '{} {} (channel {})\nPCA ({} modes) \nModel'.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = '{0} {1} (total intensity) \nModel (log scale)'.format(epoch,filt,nbands,nmodes)

plot_fig(im=im, #vmin=vmin, vmax=vmax, 
         im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_arcsec=scalebar_pix, scalebar_leg=scalebar_leg, norm=norm,
        scalebar_pad=scalebar_pad, scalebar_sep=scalebar_sep, add_scalebar_au=1, scalebar_au=scalebar_au, add_IWA=0,
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.0,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# -2.3130802828674746e-16 10.608598721762553
# The file is saved here:
#  figs/fig_v2023-9-12/2016-06-03_10modes_1+2_model_log

# %% [markdown]
# ## 2. Joint fit
#
# ### 2 epochs: polar + total intensity

# %%
epochs, filts = ['2019-07-09','2018-06-01'], ['BBH','BBH']
folder = 'results_BBH_polar+ti/' #'results_{}_{}/'.format(filt, epoch)
subfolder = 'amoeba_final/'
fn_model = 'disk_model_convolved*.fits'
fn_res = 'residuals_fm_snr*.fits'
fn_red_im = 'inputs/reduced_image*.fits'
fn_red_im_snr = 'inputs/reduced_image_snr*.fits'

# %%
config = '2023-7-17-17h56min27s_5modes_channel1/'
#config = '2023-7-17-17h28min9s_10modes_channel1/'
path_ress = np.sort(glob(infolder_results_model+folder+config+subfolder+fn_res))
path_models = np.sort(glob(infolder_results_model+folder+config+subfolder+fn_model))
path_inputs = np.sort(glob(infolder_results_model+folder+config+fn_red_im))
path_inputs_snr = np.sort(glob(infolder_results_model+folder+config+fn_red_im_snr))

nmodes = select_string_between_characs(config,'_','m',0)
nbands = select_string_between_characs(config,'l','/',-1)
print('Number of modes:', nmodes)
print('Number of bands:', nbands)
# Out:
# Number of modes: 5
# Number of bands: 1

# %% [markdown]
# #####  polar
# #### Residuals

# %%
i=1
epoch, filt, path_res, path_model, path_input, path_input_snr = epochs[i], filts[i], path_ress[i], path_models[i], path_inputs[i], path_inputs_snr[i]

# Figure
im = fits.getdata(path_res)

namesave = '{}_{}modes_{}bands_{}_res'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = -7,7
text = 'Residuals (polar)\n {} {}'.format(epoch,filt)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize,do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.02,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_BBH_polar+ti_5modes_1bands_2018-06-01_res

# %% [markdown]
# #### Synthetic model

# %%
im = fits.getdata(path_model)

namesave = '{}_{}modes_{}bands_{}_model'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = 0, np.nanmax(im)*1.2
text = 'Model (polar)\n {} {}'.format(epoch,filt)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.02,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_BBH_polar+ti_5modes_1bands_2018-06-01_model

# %% [markdown]
# #### Reduced image

# %%
im = fits.getdata(path_input)


namesave = '{}_{}modes_{}bands_{}_obs'.format(folder[:-1],nmodes,nbands,epoch)


im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = None,None
text = 'Obs $S/N$ map (polar)\n {} {}'.format(epoch,filt)

plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.02,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_BBH_polar+ti_5modes_1bands_2018-06-01_obs

# %% [markdown]
# #### Reduced image snr

# %%
im = fits.getdata(path_input_snr)


namesave = '{}_{}modes_{}bands_{}_obs_snr'.format(folder[:-1],nmodes,nbands,epoch)


im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = 0,5 # None, None
text = 'Obs $S/N$ map (polar)\n {} {}'.format(epoch,filt)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.02,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_BBH_polar+ti_5modes_1bands_2018-06-01_obs_snr

# %% [markdown]
# ##### total intensity
#
# #### Residuals

# %%
i=0
epoch, filt, path_res, path_model, path_input, path_input_snr = epochs[i], filts[i], path_ress[i], path_models[i], path_inputs[i], path_inputs_snr[i]

im = fits.getdata(path_res)

namesave = '{}_{}modes_{}bands_{}_res'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = None, None#-3, 3
#text = '{0} {1} (channel {})\nPCA ({3} modes) \nResiduals'.format(epoch,filt,nbands,nmodes)
#text = '{0} {1} (total intensity)\nPCA ({3} modes) \nResiduals'.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = 'Residuals (total intensity) \n{} {} (channel {})\nPCA ({} modes)'.format(epoch,filt,nbands,nmodes)



plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_BBH_polar+ti_5modes_1bands_2019-07-09_res

# %%
path_res
# Out:
# '/Users/desgranc/Documents/work/GitHub_clone/projects/HD102326/fm/results/results_BBH_polar+ti/2023-7-17-17h56min27s_5modes_channel1/amoeba_final/residuals_fm_snr_1_0.30min_3521_1.80.fits'

# %% [markdown]
# #### Synthetic model

# %%
im = fits.getdata(path_model)

namesave = '{}_{}modes_{}bands_{}_model'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = 0, None
#text = '{0} {1} (total intensity)\nPCA ({3} modes) \nModel'.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = 'Model (total intensity) \n{} {} (channel {})\nPCA ({} modes)'.format(epoch,filt,nbands,nmodes)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_BBH_polar+ti_5modes_1bands_2019-07-09_model

# %%
# logscale

im = fits.getdata(path_model)

namesave = '{}_{}modes_{}bands_{}_model_log'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
#im = im / np.nanmax(im)
#im = np.log10(im)
#im [im<0]=0
vmin, vmax = 0, np.nanmax(im) 
print(np.nanmin(im), np.nanmax(im))
norm = colors.LogNorm(vmin=1e-2, vmax=vmax, clip=True)
text = 'Model (total intensity) \n{} {} (channel {})\nPCA ({} modes)'.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
#text = '{0} {1} (total intensity) \nModel (log scale)'.format(epoch,filt,nbands,nmodes)

plot_fig(im=im, #vmin=vmin, vmax=vmax, 
         im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, norm=norm,
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# -1.3047202207516762e-15 28.058626809069015
# The file is saved here:
#  figs/fig_v2023-7-19/results_BBH_polar+ti_5modes_1bands_2019-07-09_model_log

# %% [markdown]
# #### Reduced image

# %%
im = fits.getdata(path_input)


namesave = '{}_{}modes_{}bands_{}_obs'.format(folder[:-1],nmodes,nbands,epoch)


im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = -3, 3
#text = '{} {} (channel {})\nPCA ({} modes) \nObs '.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = 'Obs (total intensity) \n{} {} (channel {})\nPCA ({} modes)'.format(epoch,filt,nbands,nmodes)



plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_BBH_polar+ti_5modes_1bands_2019-07-09_obs

# %% [markdown]
# #### Reduced image SNR

# %%
im = fits.getdata(path_input_snr)

namesave = '{}_{}modes_{}bands_{}_obs_snr'.format(folder[:-1],nmodes,nbands,epoch)


im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = 0, 5
#text = '{} {} (channel {})\nPCA ({} modes) \nObs '.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = 'Obs $S/N$ map (total intensity) \n{} {} (channel {})\nPCA ({} modes)'.format(epoch,filt,nbands,nmodes)



plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_BBH_polar+ti_5modes_1bands_2019-07-09_obs_snr

# %% [markdown]
# ### 3. Joint-fit 3 epochs: only total intensity

# %%
epochs, filts = ['2019-07-09','2016-04-05','2016-06-03'], ['BBH','H23','H23']
folder = 'results_3ti/' #'results_{}_{}/'.format(filt, epoch)
subfolder = 'amoeba_final/'
fn_model = 'disk_model_convolved*.fits'
fn_res = 'residuals_fm_snr*.fits'
fn_red_im = 'inputs/reduced_image*.fits'
fn_red_im_snr = 'inputs/reduced_image_snr*.fits'

# %%
config = '2023-7-19-12h44min50s_5modes_channel1/'
#config = '2023-7-18-14h54min57s_5modes_channel12/'
#config = '2023-7-18-14h55min10s_10modes_channel1/'
#config = '2023-7-18-14h55min2s_10modes_channel12/'
path_ress = np.sort(glob(infolder_results_model+folder+config+subfolder+fn_res))
path_models = np.sort(glob(infolder_results_model+folder+config+subfolder+fn_model))
path_inputs = np.sort(glob(infolder_results_model+folder+config+fn_red_im))
path_inputs_snr = np.sort(glob(infolder_results_model+folder+config+fn_red_im_snr))

nmodes = select_string_between_characs(config,'_','m',0)
nbands = select_string_between_characs(config,'l','/',-1)
print('Number of modes:', nmodes)
print('Number of bands:', nbands)
# Out:
# Number of modes: 5
# Number of bands: 1

# %% [markdown]
# ##### total intensity
#
# #### Residuals

# %%
i=2
epoch, filt, path_res, path_model, path_input, path_input_snr = epochs[i], filts[i], path_ress[i], path_models[i], path_inputs[i], path_inputs_snr[i]

im = fits.getdata(path_res)

namesave = '{}_{}modes_{}bands_{}_res'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = None, None#-3, 3
#text = '{0} {1} (channel {})\nPCA ({3} modes) \nResiduals'.format(epoch,filt,nbands,nmodes)
#text = '{0} {1} (total intensity)\nPCA ({3} modes) \nResiduals'.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = 'Residuals (total intensity) \n{} {} (channel {})\nPCA ({} modes)'.format(epoch,filt,nbands,nmodes)



plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_3ti_5modes_1bands_2016-06-03_res

# %% [markdown]
# #### Synthetic model

# %%
im = fits.getdata(path_model)

namesave = '{}_{}modes_{}bands_{}_model'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = 0, None
#text = '{0} {1} (total intensity)\nPCA ({3} modes) \nModel'.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = 'Model (total intensity) \n{} {} (channel {})\nPCA ({} modes)'.format(epoch,filt,nbands,nmodes)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_3ti_5modes_1bands_2016-06-03_model

# %%
# logscale
im = fits.getdata(path_model)

namesave = '{}_{}modes_{}bands_{}_model_log'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
#im = im / np.nanmax(im)
#im = np.log10(im)
#im [im<0]=0
vmin, vmax = 0, np.nanmax(im) 
print(np.nanmin(im), np.nanmax(im))
norm = colors.LogNorm(vmin=1e-2, vmax=vmax, clip=True)
text = 'Model (total intensity) \n{} {} (channel {})\nPCA ({} modes)'.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
#text = '{0} {1} (total intensity) \nModel (log scale)'.format(epoch,filt,nbands,nmodes)

plot_fig(im=im, #vmin=vmin, vmax=vmax, 
         im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, norm=norm,
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# -1.2708584185006092e-16 15.236262396998088
# The file is saved here:
#  figs/fig_v2023-7-19/results_3ti_5modes_1bands_2016-06-03_model_log

# %% [markdown]
# #### Reduced image

# %%
im = fits.getdata(path_input)

namesave = '{}_{}modes_{}bands_{}_obs'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = None, None
#text = '{} {} (channel {})\nPCA ({} modes) \nObs '.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = 'Obs (total intensity) \n{} {} (channel {})\nPCA ({} modes)'.format(epoch,filt,nbands,nmodes)



plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_3ti_5modes_1bands_2016-06-03_obs

# %% [markdown]
# #### Reduced image snr

# %%
im = fits.getdata(path_input_snr)


namesave = '{}_{}modes_{}bands_{}_obs_snr'.format(folder[:-1],nmodes,nbands,epoch)


im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = 0,5
#text = '{} {} (channel {})\nPCA ({} modes) \nObs '.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = 'Obs $S/N$ map (total intensity) \n{} {} (channel {})\nPCA ({} modes)'.format(epoch,filt,nbands,nmodes)



plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_3ti_5modes_1bands_2016-06-03_obs_snr

# %% [markdown]
# ### 4. Joint-fit 4 epochs: polar x1 + total intensity x3

# %%
epochs, filts = ['2019-07-09','2016-04-05', '2016-06-03', '2018-06-01'], ['BBH','H23','H23','BBH']
folder = 'results_polar+3ti_BBH_H23/' 
subfolder = 'amoeba_final/'
fn_model = 'disk_model_convolved*.fits'
fn_res = 'residuals_fm_snr*.fits'
fn_red_im = 'inputs/reduced_image*.fits'
fn_red_im_snr = 'inputs/reduced_image_snr*.fits'

# %%
config = '2023-7-19-11h22min8s_5modes_channel1/'
#config = '2023-7-19-11h23min18s_5modes_channel12/'
#config = '2023-7-19-11h23min22s_10modes_channel1/'
#config = '2023-7-19-11h23min27s_10modes_channel12/'

path_ress = np.sort(glob(infolder_results_model+folder+config+subfolder+fn_res))
path_models = np.sort(glob(infolder_results_model+folder+config+subfolder+fn_model))
path_inputs = np.sort(glob(infolder_results_model+folder+config+fn_red_im))
path_inputs_snr = np.sort(glob(infolder_results_model+folder+config+fn_red_im_snr))

nmodes = select_string_between_characs(config,'_','m',0)
nbands = select_string_between_characs(config,'l','/',-1)
print('Number of modes:', nmodes)
print('Number of bands:', nbands)
# Out:
# Number of modes: 5
# Number of bands: 1

# %% [markdown]
# #####  polar
# #### Residuals

# %%
i=3
epoch, filt, path_res, path_model, path_input, path_input_snr = epochs[i], filts[i], path_ress[i], path_models[i], path_inputs[i], path_inputs_snr[i]

# Figure
im = fits.getdata(path_res)

namesave = '{}_{}modes_{}bands_{}_res'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = -7,7
text = 'Residuals (polar)\n {} {}'.format(epoch,filt)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize,do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.02,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_polar+3ti_BBH_H23_5modes_1bands_2018-06-01_res

# %% [markdown]
# #### Synthetic model

# %%
im = fits.getdata(path_model)

namesave = '{}_{}modes_{}bands_{}_model'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = 0, np.nanmax(im)*1.2
text = 'Model (polar)\n {} {}'.format(epoch,filt)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.02,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_polar+3ti_BBH_H23_5modes_1bands_2018-06-01_model

# %% [markdown]
# #### Reduced image

# %%
im = fits.getdata(path_input)

namesave = '{}_{}modes_{}bands_{}_obs'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = None, None
text = 'Obs (polar)\n {} {}'.format(epoch,filt)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.02,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_polar+3ti_BBH_H23_5modes_1bands_2018-06-01_obs

# %% [markdown]
# #### Reduced image snr

# %%
im = fits.getdata(path_input_snr)

namesave = '{}_{}modes_{}bands_{}_obs_snr'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = 0,5 #None, None
text = 'Obs $S/N$ map (polar)\n {} {}'.format(epoch,filt)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.02,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_polar+3ti_BBH_H23_5modes_1bands_2018-06-01_obs_snr

# %% [markdown]
# ##### total intensity
#
# #### Residuals

# %%
i=1
epoch, filt, path_res, path_model, path_input, path_input_snr = epochs[i], filts[i], path_ress[i], path_models[i], path_inputs[i], path_inputs_snr[i]

im = fits.getdata(path_res)

namesave = '{}_{}modes_{}bands_{}_res'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = None, None#-3, 3
#text = '{0} {1} (channel {})\nPCA ({3} modes) \nResiduals'.format(epoch,filt,nbands,nmodes)
#text = '{0} {1} (total intensity)\nPCA ({3} modes) \nResiduals'.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = 'Residuals (total intensity) \n{} {} (channel {})\nPCA ({} modes)'.format(epoch,filt,nbands,nmodes)



plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_polar+3ti_BBH_H23_5modes_1bands_2016-04-05_res

# %% [markdown]
# #### Synthetic model

# %%
im = fits.getdata(path_model)

namesave = '{}_{}modes_{}bands_{}_model'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = 0, None
#text = '{0} {1} (total intensity)\nPCA ({3} modes) \nModel'.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = 'Model (total intensity) \n{} {} (channel {})\nPCA ({} modes)'.format(epoch,filt,nbands,nmodes)


plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_polar+3ti_BBH_H23_5modes_1bands_2016-04-05_model

# %%
# logscale
im = fits.getdata(path_model)

namesave = '{}_{}modes_{}bands_{}_model_log'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
#im = im / np.nanmax(im)
#im = np.log10(im)
#im [im<0]=0
vmin, vmax = 0, np.nanmax(im) 
print(np.nanmin(im), np.nanmax(im))
norm = colors.LogNorm(vmin=1e-2, vmax=vmax, clip=True)
text = 'Model (total intensity) \n{} {} (channel {})\nPCA ({} modes)'.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
#text = '{0} {1} (total intensity) \nModel (log scale)'.format(epoch,filt,nbands,nmodes)

plot_fig(im=im, #vmin=vmin, vmax=vmax, 
         im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, norm=norm,
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# -1.838026258971226e-16 5.0000102230380445
# The file is saved here:
#  figs/fig_v2023-7-19/results_polar+3ti_BBH_H23_5modes_1bands_2016-04-05_model_log

# %% [markdown]
# #### Reduced image

# %%
im = fits.getdata(path_input)

namesave = '{}_{}modes_{}bands_{}_obs'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = None, None
#text = '{} {} (channel {})\nPCA ({} modes) \nObs '.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = 'Obs (total intensity) \n{} {} (channel {})\nPCA ({} modes)'.format(epoch,filt,nbands,nmodes)



plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_polar+3ti_BBH_H23_5modes_1bands_2016-04-05_obs

# %% [markdown]
# #### Reduced image snr

# %%
im = fits.getdata(path_input_snr)

namesave = '{}_{}modes_{}bands_{}_obs_snr'.format(folder[:-1],nmodes,nbands,epoch)

im_crop_config = 32+6
im_crop = im_crop_config
 
print('Size of the image =', len(im), 'and crop PCA =', im_crop, 'i.e. size of the image shown =',  len(im)-2*im_crop)

clab = ''
vmin, vmax = 0, 5
#text = '{} {} (channel {})\nPCA ({} modes) \nObs '.format(epoch,filt,nbands,nmodes)
#text = '{} {} (total intensity)\n{}'.format(epoch, filt.replace('BB_',''), algo)
text = 'Obs $S/N$ map (total intensity) \n{} {} (channel {})\nPCA ({} modes)'.format(epoch,filt,nbands,nmodes)



plot_fig(im=im, vmin=vmin, vmax=vmax, im_crop=im_crop, figsize=figsize, do_tight_layout=0,
         scalebar_pix=scalebar_pix, scalebar_leg=scalebar_leg, 
         add_colorbar=add_colorbar, clab=clab, cbar_xdeb=cbar_xdeb, 
         right=right, left=left, top=top, bottom=bottom,
         add_text=1, text=text, text_xfrac=text_xfrac, text_yfrac=text_yfrac-0.07,
         saving_dir=saving_dir, save_png=save_png, namesave=namesave)
# Out:
# Size of the image = 200 and crop PCA = 38 i.e. size of the image shown = 124
# The file is saved here:
#  figs/fig_v2023-7-19/results_polar+3ti_BBH_H23_5modes_1bands_2016-04-05_obs_snr

# %% [markdown]
# # Test

# %%
lvl_contours = [5]

X, Y = np.arange(n_final), np.arange(n_final)
XX, YY = np.meshgrid(X, Y)

contours = plt.contour(XX, YY, imc, lvl_contours,
                #extent=[x_imshow[0],x_imshow[-1],y_imshow[0],y_imshow[-1]], 
                       )
plt.imshow(imc,origin='lower')
plt.clabel(contours, inline=True)
#plt.show()

# %%
def plot_fig(im, clab='', vmin=None, vmax=None, text='None', text_xfrac=0.03, text_yfrac=0.9,
        show_axis_ticks='off', im_crop=0,
        scalebar_pix=100, scalebar_leg='100 mas', platescale=12.25,
        add_colorbar=1, cbar_xdeb=0.82, right=0.8, top=0.95, left=0.01, bottom=0.05, figsize=(5,4),
        interpolation='nearest', saving_dir='', namesave='test', save_png=0, cmap='magma', norm=None,
        return_fig_ax=False, give_fig_ax=False):

    if not give_fig_ax: 
        fig, ax = plt.subplots(1,1, figsize=figsize)
    fig.subplots_adjust(left=left, right=right, top=top, bottom=bottom)
    ax.axis(show_axis_ticks)

    if im_crop != 0: im = im[im_crop:-im_crop,im_crop:-im_crop]

    if vmin != None and vmax != None: im_plot = ax.imshow(im, vmin=vmin, vmax=vmax, origin='lower', interpolation=interpolation, cmap=cmap, norm=norm)
    elif vmax != None : im_plot = ax.imshow(im, vmax=vmax, origin='lower', interpolation=interpolation, cmap=cmap, norm=norm)
    elif vmin != None : im_plot = ax.imshow(im, vmin=vmin, origin='lower', interpolation=interpolation, cmap=cmap, norm=norm)
    else : im_plot = ax.imshow(im, origin='lower', interpolation=interpolation, cmap=cmap, norm=norm)

    # Add text
    if text != 'None':
        w,h = np.shape(im)
        ax.text(w*text_xfrac,h*text_yfrac,text,color='white')

    # Add scalebar
    scalebar = AnchoredSizeBar(ax.transData, scalebar_pix/platescale, scalebar_leg, 3, label_top=True, pad=0.4,
                               sep=2, borderpad=0.5, frameon=False, size_vertical=1, color='white')#,fontproperties=fp)
    ax.add_artist(scalebar)

    # Add colorbar
    if add_colorbar:
        # Color bar
        cb_xdeb, cb_ydeb, cb_xwidth, cb_ywidth = cbar_xdeb, 0.1, 0.03, 0.8
        cb_ax = fig.add_axes([cb_xdeb, cb_ydeb, cb_xwidth, cb_ywidth])

        cbar = fig.colorbar(im_plot, cax=cb_ax, orientation='vertical', #drawedges=True,
                            pad=0.8, shrink=0.05,fraction=0.01,aspect=50)#,width_fraction=0.001)

        cbar.set_label(clab)
    
    if return_fig_ax: return fig, ax
    else: 
        print('The file is saved here:\n', saving_dir+namesave)
        plt.savefig(saving_dir+namesave+'.pdf')
        if save_png: plt.savefig(saving_dir+namesave+'.png', dpi=200)
        plt.show()

# %%
def plot_fig(im, clab='', vmin=None, vmax=None, text='None', text_xfrac=0.03, text_yfrac=0.9, color_text='white', add_text=0,
        show_axis_ticks='off', im_crop=0, platescale_use_binning_factor=0, binning_factor=None, flux_use_binning_factor=0,
        scalebar_arcsec=0.1, scalebar_leg='0.1"', scalebar_loc=3, platescale=12.25, 
        scalebar_color='white', scalebar_pad=0.4, scalebar_sep=2, scalebar_borderpad=0.5, scalebar_label_top=False,
        add_scalebar_au=1, scalebar_au='',
        add_IWA=1, r_IWA = 100, IWA_color = [0.8,0.8,0.8],
        add_colorbar=1, cbar_xdeb=0.82, cbar_ydeb=0.1, cbar_xwidth=0.03, cbar_ywidth=0.8,
        cbar_edges_nb=None, cbar_bound=None,
        right=0.8, top=0.95, left=0.01, bottom=0.05, figsize=(5,4),
        interpolation='nearest', saving_dir='', namesave='test', save_png=0, cmap='magma',norm=None, do_tight_layout=1,
        return_fig_ax=False, give_fig_ax=False, fig=None, ax=None, show=1):

    if not give_fig_ax: 
        fig, ax = plt.subplots(1,1, figsize=figsize)
        fig.subplots_adjust(left=left, right=right, top=top, bottom=bottom)
    ax.axis(show_axis_ticks)

    if im_crop != 0: im = im[im_crop:-im_crop,im_crop:-im_crop]

    if vmin != None and vmax != None: im_plot = ax.imshow(im, vmin=vmin, vmax=vmax, origin='lower', interpolation=interpolation, cmap=cmap, norm=norm)
    elif vmax != None : im_plot = ax.imshow(im, vmax=vmax, origin='lower', interpolation=interpolation, cmap=cmap, norm=norm)
    elif vmin != None : im_plot = ax.imshow(im, vmin=vmin, origin='lower', interpolation=interpolation, cmap=cmap, norm=norm)
    else : im_plot = ax.imshow(im, origin='lower', interpolation=interpolation, cmap=cmap, norm=norm)

    # Add text
    if add_text:
        w,h = np.shape(im)
        ax.text(w*text_xfrac,h*text_yfrac,text,color=color_text)

    # Add scalebar
    if platescale_use_binning_factor: factor = binning_factor[i]
    else: factor = 1
    size = scalebar_arcsec/(platescale*factor)
    scalebar = AnchoredSizeBar(ax.transData, size, scalebar_leg, scalebar_loc, label_top=scalebar_label_top, pad=scalebar_pad,
                               sep=scalebar_sep, borderpad=scalebar_borderpad, frameon=False, size_vertical=2/factor, color=scalebar_color)#,fontproperties=fp)
    ax.add_artist(scalebar)
    
    # Add scale bar au
    if add_scalebar_au:
        ax.text(text_xfrac*0.8,0.155, scalebar_au, color=color_text, transform=ax.transAxes)

    # Add colorbar
    if add_colorbar:
        # Color bar
        cb_xdeb, cb_ydeb, cb_xwidth, cb_ywidth = cbar_xdeb, cbar_ydeb, cbar_xwidth, cbar_ywidth
        cb_ax = fig.add_axes([cb_xdeb, cb_ydeb, cb_xwidth, cb_ywidth])

        # Cbar edges
        if cbar_edges_nb != None: 
            cbar_labels = np.linspace(vmin,vmax,cbar_edges_nb)
            cbar_bound  = np.linspace(vmin,vmax,cbar_edges_nb)
    
        cbar = fig.colorbar(im_plot, cax=cb_ax, orientation='vertical', 
                            boundaries=cbar_bound, drawedges=True,
                            pad=0.8, shrink=0.05,fraction=0.01,aspect=50)#,width_fraction=0.001)
        cbar.set_label(clab)
        #cbar.set_ticklabels(cbar_labels)
     

    # Add IWA
    if add_IWA:
        h, w = np.shape(im)[0], np.shape(im)[1]
        circle = Circle((h/2,w/2),r_IWA/platescale,ec=IWA_color,fc=IWA_color,ls='-',lw=1)
        ax.add_patch(circle) 
        
    if do_tight_layout: plt.tight_layout()
        
    if return_fig_ax: return fig, ax
    else: 
        print('The file is saved here:\n', saving_dir+namesave)
        plt.savefig(saving_dir+namesave+'.pdf', dpi=300)
        if save_png: plt.savefig(saving_dir+namesave+'.png', dpi=200)
    if show: plt.show()
        
        
    
    return
